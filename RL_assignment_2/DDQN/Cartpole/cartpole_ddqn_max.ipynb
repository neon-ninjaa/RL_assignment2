# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import gym
import numpy as np
import random
from collections import namedtuple, deque
import wandb

GAMMA=0.99

class QNetwork1(nn.Module):
    def __init__(self, state_size, action_size, seed, fc1_units=128, fc2_units=64):
        super(QNetwork1, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.fc1 = nn.Linear(state_size, fc1_units)
        self.fc2 = nn.Linear(fc1_units, fc2_units)
        self.fc_advantage = nn.Linear(fc2_units, action_size)
        self.fc_value = nn.Linear(fc2_units, 1)

    def forward(self, state):
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        value = self.fc_value(x)
        advantage = self.fc_advantage(x)
        Q_values = value + (advantage - advantage.max(dim=1, keepdim=True)[0])
        return Q_values
    
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

class ReplayBuffer:
    def __init__(self, action_size, buffer_size, batch_size, seed):
        self.action_size = action_size
        self.memory = deque(maxlen=buffer_size)
        self.batch_size = batch_size
        self.experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"])
        self.seed = random.seed(seed)

    def add(self, state, action, reward, next_state, done):
        e = self.experience(state, action, reward, next_state, done)
        self.memory.append(e)

    def sample(self):
        experiences = random.sample(self.memory, k=self.batch_size)
        states = torch.from_numpy(np.vstack([e.state for e in experiences if e is not None])).float().to(device)
        actions = torch.from_numpy(np.vstack([e.action for e in experiences if e is not None])).long().to(device)
        rewards = torch.from_numpy(np.vstack([e.reward for e in experiences if e is not None])).float().to(device)
        next_states = torch.from_numpy(np.vstack([e.next_state for e in experiences if e is not None])).float().to(device)
        dones = torch.from_numpy(np.vstack([e.done for e in experiences if e is not None]).astype(np.uint8)).float().to(device)
        return (states, actions, rewards, next_states, dones)

    def __len__(self):
        return len(self.memory)

class TutorialAgent1:
    def __init__(self, state_size, action_size, seed, lr, update_every, buffer_size, batch_size):
        self.state_size = state_size
        print(update_every)
        self.action_size = action_size
        self.seed = random.seed(seed)
        self.qnetwork_local = QNetwork1(state_size, action_size, seed).to(device)
        self.qnetwork_target = QNetwork1(state_size, action_size, seed).to(device)
        self.optimizer = optim.Adam(self.qnetwork_local.parameters(), lr=lr)
        self.memory = ReplayBuffer(action_size, buffer_size, batch_size, seed)
        self.t_step = 0
        self.update_every = update_every
        self.batch_size = batch_size

    def step(self, state, action, reward, next_state, done):
        self.memory.add(state, action, reward, next_state, done)
        if len(self.memory) >= self.batch_size:
            experiences = self.memory.sample()
            self.learn(experiences, GAMMA)
        self.t_step = (self.t_step + 1) % self.update_every
        if self.t_step == 0:
            self.qnetwork_target.load_state_dict(self.qnetwork_local.state_dict())

    def act(self, state, eps=0.):
        state = torch.from_numpy(state).float().unsqueeze(0).to(device)
        self.qnetwork_local.eval()
        with torch.no_grad():
            action_values = self.qnetwork_local(state)
        self.qnetwork_local.train()
        if random.random() > eps:
            return np.argmax(action_values.cpu().data.numpy())
        else:
            return random.choice(np.arange(self.action_size))

    def learn(self, experiences, gamma):
        states, actions, rewards, next_states, dones = experiences
        Q_targets_next = self.qnetwork_target(next_states)
        next_state_values = self.qnetwork_target(next_states).detach().max(1)[0].unsqueeze(1)
        Q_targets = rewards + (gamma * next_state_values * (1 - dones))
        Q_expected = self.qnetwork_local(states).gather(1, actions)
        loss = F.mse_loss(Q_expected, Q_targets)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
import matplotlib.pyplot as plt
def dqn(agent, env, n_episodes=10000, max_t=500, eps_start=1.0, eps_end=0.01, eps_decay=0.995):
    scores_window = deque(maxlen=100)
    all_scores = np.array([])
    moving_avg_scores = np.array([])
    eps = eps_start
    for i_episode in range(1, n_episodes+1):
        state,_ = env.reset()
        score = 0
        for t in range(max_t):
            action = agent.act(state, eps)
            next_state, reward, done, truncated,_ = env.step(action)
            agent.step(state, action, reward, next_state, done)
            state = next_state
            score += reward
            if done or truncated:
                break
        scores_window.append(score)
        all_scores = np.append(all_scores, score)
        eps = max(eps_end, eps_decay * eps)
        moving_avg_scores = np.append(moving_avg_scores, np.mean(scores_window))
        if i_episode == 250:
            break
    # plt.plot(np.arange(len(moving_avg_scores)), moving_avg_scores)
    # plt.ylabel('Moving Average Scores')
    # plt.xlabel('Episode #')
    # plt.title('Moving Average Scores over Episodes')
    # plt.show()
    return moving_avg_scores, True

def train_agent(lr, update_every, buffer_size, batch_size):
    env = gym.make('CartPole-v1')
    print(update_every)
    print(buffer_size)
    print(batch_size)
    state_shape = env.observation_space.shape[0]
    action_shape = env.action_space.n
    agent = TutorialAgent1(state_size=state_shape, action_size=action_shape, seed=0, lr=lr,
                           update_every=update_every, buffer_size=buffer_size, batch_size=batch_size)
    all_scores_1, _ = dqn(agent, env)
    regret = 0
    for i in all_scores_1:
        if i > 195:
            break
        else:
            regret += 195 - i
    return regret,all_scores_1

def run_training():
    config_defaults = {
        "lr": 5e-4,
        "update_every": 50,
        "buffer_size": 1e5,
        "batch_size": 64
    }
    config = wandb.init(config=config_defaults, project="dueling_max_cartpole")
    lr = config.config["lr"]
    update_every = config.config['update_every']
    batch_size = config.config["batch_size"]
    buffer_size = config.config["buffer_size"]
    regret,all_scores= train_agent(lr, update_every, buffer_size, batch_size)
    for i in all_scores:
        wandb.log({"mean_scores":i})
    wandb.log({"regret": regret})

sweep_config = {
    "method": "bayes",
    "metric": {"name": "regret", "goal": "minimize"},
    "parameters": {
        "lr": {"min": 1e-5, "max": 1e-2},
        "update_every": {"values": [20, 50, 75, 100]},
        "buffer_size": {"values": [ 1e2,1e3, 1e5]},
        "batch_size": {"values": [32, 64, 128]}
    },
    "project": "dueling_max_cartpole",
    "early_terminate": {
        "type": "hyperband",
        "min_iter": 3,
        "max_iter": 100
    }
}

sweep_id = wandb.sweep(sweep_config)
wandb.agent(sweep_id, function=run_training)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Create sweep with ID: 2ssb7pwi
# Sweep URL: https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi
# wandb: Agent Starting Run: tvr15ov0 with config:
# wandb: 	batch_size: 128
# wandb: 	buffer_size: 100
# wandb: 	lr: 0.00918765475565439
# wandb: 	update_every: 75
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: shobhith-v (rl_shobhith). Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb version 0.16.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>c:\Users\Shobhith Vadlamudi\Desktop\3rd Year\SEM 6\RL\wandb\run-20240404_154858-tvr15ov0</code>
# Syncing run <strong><a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/tvr15ov0/workspace' target="_blank">ethereal-sweep-1</a></strong> to <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View project at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole</a>
#  View sweep at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View run at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/tvr15ov0/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/tvr15ov0/workspace</a>
# 75
# 100
# 128
# 75
# C:\Users\Shobhith Vadlamudi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>▄▄▆███▇▇▇▇▆▆▆▆▆▆▆▆▅▅▄▄▄▄▃▃▃▃▂▂▂▂▂▁▁▁▁▁▁▁</td></tr><tr><td>regret</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>11.71</td></tr><tr><td>regret</td><td>44571.12264</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ethereal-sweep-1</strong> at: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/tvr15ov0/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/tvr15ov0/workspace</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240404_154858-tvr15ov0\logs</code>
# wandb: Agent Starting Run: qiohigpi with config:
# wandb: 	batch_size: 128
# wandb: 	buffer_size: 1000
# wandb: 	lr: 0.006938038829321627
# wandb: 	update_every: 20
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb version 0.16.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>c:\Users\Shobhith Vadlamudi\Desktop\3rd Year\SEM 6\RL\wandb\run-20240404_154910-qiohigpi</code>
# Syncing run <strong><a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/qiohigpi/workspace' target="_blank">stellar-sweep-2</a></strong> to <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View project at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole</a>
#  View sweep at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View run at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/qiohigpi/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/qiohigpi/workspace</a>
# 20
# 1000
# 128
# 20
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>▁▂▁▁▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▃▃▃▃▄▄▄▅▆▆▆▆▆▇▇█</td></tr><tr><td>regret</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>100.84</td></tr><tr><td>regret</td><td>37680.33069</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">stellar-sweep-2</strong> at: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/qiohigpi/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/qiohigpi/workspace</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240404_154910-qiohigpi\logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: j4gnnu3x with config:
# wandb: 	batch_size: 128
# wandb: 	buffer_size: 100000
# wandb: 	lr: 0.006782591437216842
# wandb: 	update_every: 50
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb version 0.16.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>c:\Users\Shobhith Vadlamudi\Desktop\3rd Year\SEM 6\RL\wandb\run-20240404_155045-j4gnnu3x</code>
# Syncing run <strong><a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/j4gnnu3x/workspace' target="_blank">smooth-sweep-3</a></strong> to <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View project at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole</a>
#  View sweep at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View run at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/j4gnnu3x/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/j4gnnu3x/workspace</a>
# 50
# 100000
# 128
# 50
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>▁▁▁▁▂▂▂▃▃▃▃▃▃▃▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▆▆▇▇▇▇▇███</td></tr><tr><td>regret</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>57.72</td></tr><tr><td>regret</td><td>39598.70397</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">smooth-sweep-3</strong> at: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/j4gnnu3x/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/j4gnnu3x/workspace</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240404_155045-j4gnnu3x\logs</code>
# wandb: Agent Starting Run: rp2ipcnt with config:
# wandb: 	batch_size: 128
# wandb: 	buffer_size: 100000
# wandb: 	lr: 0.006816045466212297
# wandb: 	update_every: 20
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb version 0.16.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>c:\Users\Shobhith Vadlamudi\Desktop\3rd Year\SEM 6\RL\wandb\run-20240404_155150-rp2ipcnt</code>
# Syncing run <strong><a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/rp2ipcnt/workspace' target="_blank">swift-sweep-4</a></strong> to <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View project at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole</a>
#  View sweep at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View run at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/rp2ipcnt/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/rp2ipcnt/workspace</a>
# 20
# 100000
# 128
# 20
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>▁▁▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▅▅▅▅▆▇█</td></tr><tr><td>regret</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>98.68</td></tr><tr><td>regret</td><td>38849.72163</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">swift-sweep-4</strong> at: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/rp2ipcnt/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/rp2ipcnt/workspace</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240404_155150-rp2ipcnt\logs</code>
# wandb: Agent Starting Run: hyqbp1lg with config:
# wandb: 	batch_size: 128
# wandb: 	buffer_size: 100000
# wandb: 	lr: 0.006925787031892141
# wandb: 	update_every: 20
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb version 0.16.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>c:\Users\Shobhith Vadlamudi\Desktop\3rd Year\SEM 6\RL\wandb\run-20240404_155337-hyqbp1lg</code>
# Syncing run <strong><a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/hyqbp1lg/workspace' target="_blank">decent-sweep-5</a></strong> to <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View project at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole</a>
#  View sweep at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View run at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/hyqbp1lg/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/hyqbp1lg/workspace</a>
# 20
# 100000
# 128
# 20
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>▁▁▁▂▁▁▂▂▃▂▂▂▂▂▂▂▂▃▃▃▃▃▃▃▃▃▃▃▃▄▄▅▆▇██████</td></tr><tr><td>regret</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>62.68</td></tr><tr><td>regret</td><td>39803.71671</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">decent-sweep-5</strong> at: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/hyqbp1lg/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/hyqbp1lg/workspace</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240404_155337-hyqbp1lg\logs</code>
# wandb: Agent Starting Run: riwf3wz0 with config:
# wandb: 	batch_size: 128
# wandb: 	buffer_size: 1000
# wandb: 	lr: 0.0023449658940296733
# wandb: 	update_every: 100
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb version 0.16.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>c:\Users\Shobhith Vadlamudi\Desktop\3rd Year\SEM 6\RL\wandb\run-20240404_155501-riwf3wz0</code>
# Syncing run <strong><a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/riwf3wz0/workspace' target="_blank">helpful-sweep-6</a></strong> to <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View project at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole</a>
#  View sweep at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View run at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/riwf3wz0/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/riwf3wz0/workspace</a>
# 100
# 1000
# 128
# 100
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>▁▂▂▂▂▂▂▂▂▂▂▃▃▃▃▃▃▃▃▃▃▃▄▄▄▄▄▄▅▅▆▅▅▆▆▆▇▇██</td></tr><tr><td>regret</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>90.92</td></tr><tr><td>regret</td><td>36866.45067</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">helpful-sweep-6</strong> at: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/riwf3wz0/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/riwf3wz0/workspace</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240404_155501-riwf3wz0\logs</code>
# wandb: Agent Starting Run: yua9wj0v with config:
# wandb: 	batch_size: 32
# wandb: 	buffer_size: 100000
# wandb: 	lr: 0.0017770833987536556
# wandb: 	update_every: 100
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb version 0.16.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>c:\Users\Shobhith Vadlamudi\Desktop\3rd Year\SEM 6\RL\wandb\run-20240404_155703-yua9wj0v</code>
# Syncing run <strong><a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/yua9wj0v/workspace' target="_blank">fine-sweep-7</a></strong> to <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View project at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole</a>
#  View sweep at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View run at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/yua9wj0v/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/yua9wj0v/workspace</a>
# 100
# 100000
# 32
# 100
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▄▄▅▅▅▅▅▆▆▆▆▆▇▆▆▇▇▇▇▇████</td></tr><tr><td>regret</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>80.42</td></tr><tr><td>regret</td><td>36622.98997</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fine-sweep-7</strong> at: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/yua9wj0v/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/yua9wj0v/workspace</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240404_155703-yua9wj0v\logs</code>
# wandb: Agent Starting Run: mrfksgxy with config:
# wandb: 	batch_size: 64
# wandb: 	buffer_size: 100000
# wandb: 	lr: 0.005877820734947816
# wandb: 	update_every: 75
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb version 0.16.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>c:\Users\Shobhith Vadlamudi\Desktop\3rd Year\SEM 6\RL\wandb\run-20240404_155823-mrfksgxy</code>
# Syncing run <strong><a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/mrfksgxy/workspace' target="_blank">revived-sweep-8</a></strong> to <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View project at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole</a>
#  View sweep at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View run at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/mrfksgxy/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/mrfksgxy/workspace</a>
# 75
# 100000
# 64
# 75
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>▁▂▂▂▂▂▃▃▃▃▃▃▃▃▄▃▄▄▄▄▅▅▅▅▅▅▅▅▆▆▆▆▆▆▇▇████</td></tr><tr><td>regret</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>63.49</td></tr><tr><td>regret</td><td>39337.54923</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">revived-sweep-8</strong> at: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/mrfksgxy/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/mrfksgxy/workspace</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240404_155823-mrfksgxy\logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 3eu7mdo9 with config:
# wandb: 	batch_size: 128
# wandb: 	buffer_size: 1000
# wandb: 	lr: 0.006933035606962835
# wandb: 	update_every: 75
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>c:\Users\Shobhith Vadlamudi\Desktop\3rd Year\SEM 6\RL\wandb\run-20240404_160018-3eu7mdo9</code>
# Syncing run <strong><a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/3eu7mdo9/workspace' target="_blank">elated-sweep-9</a></strong> to <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View project at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole</a>
#  View sweep at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View run at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/3eu7mdo9/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/3eu7mdo9/workspace</a>
# 75
# 1000
# 128
# 75
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>▁▂▂▂▂▂▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▄▄▄▄▅▅▅▆▆▆▇▇▇▇▇████</td></tr><tr><td>regret</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>67.09</td></tr><tr><td>regret</td><td>39176.33306</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">elated-sweep-9</strong> at: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/3eu7mdo9/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/3eu7mdo9/workspace</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240404_160018-3eu7mdo9\logs</code>
# wandb: Agent Starting Run: r2i4fu4u with config:
# wandb: 	batch_size: 32
# wandb: 	buffer_size: 100000
# wandb: 	lr: 0.005378875846062624
# wandb: 	update_every: 100
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01127777777777131, max=1.0)…
# wandb version 0.16.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>c:\Users\Shobhith Vadlamudi\Desktop\3rd Year\SEM 6\RL\wandb\run-20240404_160200-r2i4fu4u</code>
# Syncing run <strong><a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/r2i4fu4u/workspace' target="_blank">fallen-sweep-10</a></strong> to <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View project at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole</a>
#  View sweep at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View run at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/r2i4fu4u/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/r2i4fu4u/workspace</a>
# 100
# 100000
# 32
# 100
# VBox(children=(Label(value='0.001 MB of 0.006 MB uploaded\r'), FloatProgress(value=0.19432756739909615, max=1.…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>▁▂▂▂▂▂▂▃▃▃▃▃▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇█</td></tr><tr><td>regret</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>74.57</td></tr><tr><td>regret</td><td>38009.09716</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fallen-sweep-10</strong> at: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/r2i4fu4u/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/r2i4fu4u/workspace</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240404_160200-r2i4fu4u\logs</code>
# wandb: Agent Starting Run: s0wm734w with config:
# wandb: 	batch_size: 128
# wandb: 	buffer_size: 100
# wandb: 	lr: 0.003505753644476448
# wandb: 	update_every: 20
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb version 0.16.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>c:\Users\Shobhith Vadlamudi\Desktop\3rd Year\SEM 6\RL\wandb\run-20240404_160320-s0wm734w</code>
# Syncing run <strong><a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/s0wm734w/workspace' target="_blank">balmy-sweep-11</a></strong> to <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View project at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole</a>
#  View sweep at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View run at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/s0wm734w/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/s0wm734w/workspace</a>
# 20
# 100
# 128
# 20
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>▂███▇▇▇▇▇▇▇▆▆▆▅▅▅▅▄▄▄▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>regret</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>11.75</td></tr><tr><td>regret</td><td>44159.59876</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">balmy-sweep-11</strong> at: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/s0wm734w/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/s0wm734w/workspace</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240404_160320-s0wm734w\logs</code>
# wandb: Agent Starting Run: 6mr6fhw2 with config:
# wandb: 	batch_size: 64
# wandb: 	buffer_size: 100
# wandb: 	lr: 0.0068894966596074235
# wandb: 	update_every: 75
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb version 0.16.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>c:\Users\Shobhith Vadlamudi\Desktop\3rd Year\SEM 6\RL\wandb\run-20240404_160336-6mr6fhw2</code>
# Syncing run <strong><a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/6mr6fhw2/workspace' target="_blank">eager-sweep-12</a></strong> to <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View project at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole</a>
#  View sweep at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View run at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/6mr6fhw2/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/6mr6fhw2/workspace</a>
# 75
# 100
# 64
# 75
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>▁▁▁▁▁▁▂▂▂▂▂▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▆▆▆▇▇█</td></tr><tr><td>regret</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>117.36</td></tr><tr><td>regret</td><td>37021.83016</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">eager-sweep-12</strong> at: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/6mr6fhw2/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/6mr6fhw2/workspace</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240404_160336-6mr6fhw2\logs</code>
# wandb: Agent Starting Run: 88e77ytj with config:
# wandb: 	batch_size: 32
# wandb: 	buffer_size: 100000
# wandb: 	lr: 0.00952416642990107
# wandb: 	update_every: 75
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb version 0.16.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>c:\Users\Shobhith Vadlamudi\Desktop\3rd Year\SEM 6\RL\wandb\run-20240404_160515-88e77ytj</code>
# Syncing run <strong><a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/88e77ytj/workspace' target="_blank">logical-sweep-13</a></strong> to <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View project at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole</a>
#  View sweep at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View run at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/88e77ytj/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/88e77ytj/workspace</a>
# 75
# 100000
# 32
# 75
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▄▅▅▅▅▅▅▅▅▅▆▆▆▆▇▇▇████</td></tr><tr><td>regret</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>56.9</td></tr><tr><td>regret</td><td>39666.5899</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">logical-sweep-13</strong> at: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/88e77ytj/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/88e77ytj/workspace</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240404_160515-88e77ytj\logs</code>
# wandb: Agent Starting Run: fl354ri5 with config:
# wandb: 	batch_size: 128
# wandb: 	buffer_size: 100
# wandb: 	lr: 0.004298634552240046
# wandb: 	update_every: 50
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb version 0.16.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>c:\Users\Shobhith Vadlamudi\Desktop\3rd Year\SEM 6\RL\wandb\run-20240404_160618-fl354ri5</code>
# Syncing run <strong><a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/fl354ri5/workspace' target="_blank">clear-sweep-14</a></strong> to <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View project at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole</a>
#  View sweep at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View run at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/fl354ri5/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/fl354ri5/workspace</a>
# 50
# 100
# 128
# 50
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>█▇▆▆▅▄▄▄▄▄▄▄▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>regret</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>11.97</td></tr><tr><td>regret</td><td>44130.30673</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">clear-sweep-14</strong> at: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/fl354ri5/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/fl354ri5/workspace</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240404_160618-fl354ri5\logs</code>
# wandb: Agent Starting Run: iyd2ya3k with config:
# wandb: 	batch_size: 64
# wandb: 	buffer_size: 1000
# wandb: 	lr: 0.008935053240910141
# wandb: 	update_every: 100
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb version 0.16.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>c:\Users\Shobhith Vadlamudi\Desktop\3rd Year\SEM 6\RL\wandb\run-20240404_160638-iyd2ya3k</code>
# Syncing run <strong><a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/iyd2ya3k/workspace' target="_blank">resilient-sweep-15</a></strong> to <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View project at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole</a>
#  View sweep at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View run at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/iyd2ya3k/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/iyd2ya3k/workspace</a>
# 100
# 1000
# 64
# 100
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>▁▂▂▂▂▂▂▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▄▄▄▅▅▆▆▇▇▇██</td></tr><tr><td>regret</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>72.12</td></tr><tr><td>regret</td><td>39473.04991</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">resilient-sweep-15</strong> at: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/iyd2ya3k/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/iyd2ya3k/workspace</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240404_160638-iyd2ya3k\logs</code>
# wandb: Agent Starting Run: 8dhmmar3 with config:
# wandb: 	batch_size: 128
# wandb: 	buffer_size: 100000
# wandb: 	lr: 0.001462965709725362
# wandb: 	update_every: 20
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb version 0.16.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>c:\Users\Shobhith Vadlamudi\Desktop\3rd Year\SEM 6\RL\wandb\run-20240404_160921-8dhmmar3</code>
# Syncing run <strong><a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/8dhmmar3/workspace' target="_blank">leafy-sweep-16</a></strong> to <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View project at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole</a>
#  View sweep at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View run at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/8dhmmar3/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/8dhmmar3/workspace</a>
# 20
# 100000
# 128
# 20
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>▁▂▂▂▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▆▆▆▆▆▆▆▆▆▆▇█▇█▇▇▇██</td></tr><tr><td>regret</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>81.16</td></tr><tr><td>regret</td><td>36401.27456</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">leafy-sweep-16</strong> at: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/8dhmmar3/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/8dhmmar3/workspace</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240404_160921-8dhmmar3\logs</code>
# wandb: Agent Starting Run: xviev2b3 with config:
# wandb: 	batch_size: 128
# wandb: 	buffer_size: 100000
# wandb: 	lr: 0.0050963961615036555
# wandb: 	update_every: 50
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb version 0.16.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.5
# ...
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb version 0.16.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>c:\Users\Shobhith Vadlamudi\Desktop\3rd Year\SEM 6\RL\wandb\run-20240405_010224-0wbj31nk</code>
# Syncing run <strong><a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/0wbj31nk/workspace' target="_blank">robust-sweep-169</a></strong> to <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View project at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole</a>
#  View sweep at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View run at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/0wbj31nk/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/0wbj31nk/workspace</a>
# 50
# 1000
# 32
# 50
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>▁▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▃▃▃▃▃▃▃▃▄▄▄▄▄▄▄▅▅▆▇▇▇▇██</td></tr><tr><td>regret</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>93.21</td></tr><tr><td>regret</td><td>37341.88585</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">robust-sweep-169</strong> at: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/0wbj31nk/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/0wbj31nk/workspace</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240405_010224-0wbj31nk\logs</code>
# wandb: Agent Starting Run: 27kytb6z with config:
# wandb: 	batch_size: 32
# wandb: 	buffer_size: 100
# wandb: 	lr: 0.0033851372393312626
# wandb: 	update_every: 50
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb version 0.16.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>c:\Users\Shobhith Vadlamudi\Desktop\3rd Year\SEM 6\RL\wandb\run-20240405_011055-27kytb6z</code>
# Syncing run <strong><a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/27kytb6z/workspace' target="_blank">blooming-sweep-170</a></strong> to <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View project at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole</a>
#  View sweep at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View run at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/27kytb6z/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/27kytb6z/workspace</a>
# 50
# 100
# 32
# 50
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>▁▁▁▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▅▅▅▅▅▆▆▇▇▇▇██</td></tr><tr><td>regret</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>129.68</td></tr><tr><td>regret</td><td>34639.93306</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">blooming-sweep-170</strong> at: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/27kytb6z/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/27kytb6z/workspace</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240405_011055-27kytb6z\logs</code>
# wandb: Agent Starting Run: 1wqngpc2 with config:
# wandb: 	batch_size: 128
# wandb: 	buffer_size: 1000
# wandb: 	lr: 0.0010543150487297226
# wandb: 	update_every: 50
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb version 0.16.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>c:\Users\Shobhith Vadlamudi\Desktop\3rd Year\SEM 6\RL\wandb\run-20240405_011855-1wqngpc2</code>
# Syncing run <strong><a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/1wqngpc2/workspace' target="_blank">vague-sweep-171</a></strong> to <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View project at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole</a>
#  View sweep at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View run at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/1wqngpc2/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/1wqngpc2/workspace</a>
# 50
# 1000
# 128
# 50
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>▁▁▁▁▁▁▂▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▅▆▆▆▇████</td></tr><tr><td>regret</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>108.07</td></tr><tr><td>regret</td><td>34470.32601</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">vague-sweep-171</strong> at: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/1wqngpc2/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/1wqngpc2/workspace</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240405_011855-1wqngpc2\logs</code>
# wandb: Agent Starting Run: vvo9ndwo with config:
# wandb: 	batch_size: 64
# wandb: 	buffer_size: 100
# wandb: 	lr: 0.0006047660201799364
# wandb: 	update_every: 75
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb version 0.16.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>c:\Users\Shobhith Vadlamudi\Desktop\3rd Year\SEM 6\RL\wandb\run-20240405_013119-vvo9ndwo</code>
# Syncing run <strong><a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/vvo9ndwo/workspace' target="_blank">polar-sweep-172</a></strong> to <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View project at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole</a>
#  View sweep at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View run at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/vvo9ndwo/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/vvo9ndwo/workspace</a>
# 75
# 100
# 64
# 75
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▂▃▃▃▃▄▄▄▅▅▅▆▆▆▇▇▇▇█</td></tr><tr><td>regret</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>244.72</td></tr><tr><td>regret</td><td>27516.58015</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">polar-sweep-172</strong> at: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/vvo9ndwo/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/vvo9ndwo/workspace</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240405_013119-vvo9ndwo\logs</code>
# wandb: Agent Starting Run: qprbqtq2 with config:
# wandb: 	batch_size: 64
# wandb: 	buffer_size: 100
# wandb: 	lr: 0.006295313741733877
# wandb: 	update_every: 100
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb version 0.16.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>c:\Users\Shobhith Vadlamudi\Desktop\3rd Year\SEM 6\RL\wandb\run-20240405_014150-qprbqtq2</code>
# Syncing run <strong><a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/qprbqtq2/workspace' target="_blank">ethereal-sweep-173</a></strong> to <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View project at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole</a>
#  View sweep at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View run at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/qprbqtq2/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/qprbqtq2/workspace</a>
# 100
# 100
# 64
# 100
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▇▇██</td></tr><tr><td>regret</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>mean_scores</td><td>139.09</td></tr><tr><td>regret</td><td>34814.77565</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ethereal-sweep-173</strong> at: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/qprbqtq2/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/qprbqtq2/workspace</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240405_014150-qprbqtq2\logs</code>
# wandb: Agent Starting Run: an3aac0z with config:
# wandb: 	batch_size: 128
# wandb: 	buffer_size: 100000
# wandb: 	lr: 0.008916164464892481
# wandb: 	update_every: 50
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb version 0.16.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>c:\Users\Shobhith Vadlamudi\Desktop\3rd Year\SEM 6\RL\wandb\run-20240405_014801-an3aac0z</code>
# Syncing run <strong><a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/an3aac0z/workspace' target="_blank">glad-sweep-174</a></strong> to <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View project at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole</a>
#  View sweep at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/sweeps/2ssb7pwi</a>
#  View run at <a href='https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/an3aac0z/workspace' target="_blank">https://wandb.ai/rl_shobhith/dueling_max_cartpole/runs/an3aac0z/workspace</a>
# 50
# 100000
# 128
# 50
